# %%
import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
carpics= glob.glob('../../data/**/*.jpg', recursive=True)

# %%
image=[]
for i in range(16):
    image.append(plt.imread(carpics[i]))

# %%
plt.figure(figsize=(10, 10))

for category_num in range(1,17):
    plt.subplot(4, 4, category_num)
    plt.imshow(image[category_num-1]).axes.get_yaxis().set_visible(False)#)
    plt.xticks([])
    
plt.subplots_adjust(wspace=0.0, hspace=0.0)
plt.show()

# %%
len(carpics)
# Out:
# 46024

# %%
model=[]
carbody=[]
doors=[]
for cars in carpics:
    #print(cars)
    model.append(cars.split("/")[3])
    carbody.append(cars.split("/")[5])
    doors.append(cars.split("/")[6])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
#sns.set_style('green')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-152-d2ce6652e786> in <module>()
#       1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
# ----> 3 sns.set_style('green')
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/rcmod.py in set_style(style, rc)
#     285
#     286     """
# --> 287     style_object = axes_style(style, rc)
#     288     mpl.rcParams.update(style_object)
#     289
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/rcmod.py in axes_style(style, rc)
#     167         styles = ["white", "dark", "whitegrid", "darkgrid", "ticks"]
#     168         if style not in styles:
# --> 169             raise ValueError("style must be one of %s" % ", ".join(styles))
#     170
#     171         # Define colors here
#
# ValueError: style must be one of white, dark, whitegrid, darkgrid, ticks

# %%
#arr = np.array(['a','a','b','b','b','c'])
modeldict=dict(set(map(lambda x  : (x , model.count(x)) , model)))
carbodydict=dict(set(map(lambda x  : (x , carbody.count(x)) , carbody)))
doorsdict=dict(set(map(lambda x  : (x , doors.count(x)) , doors)))

# %%
pd_df = pd.DataFrame(list(modeldict.items()))
pd_df.columns =["Model","Count"]
pd_df = pd_df.sort_values(['Count']).reset_index(drop=True)

# %%
pd_df
# Out:
#                Model  Count
# 0           model_Z1    141
# 1           model_M5    159
# 2           model_Z8    180
# 3           model_i8    235
# 4         model_X4 M    250
# 5           model_M6    456
# 6         model_X6 M    734
# 7           model_M2    811
# 8           model_Z4   1004
# 9         model_X5 M   1051
# 10  model_6er (alle)   1123
# 11          model_X2   1403
# 12          model_Z3   1424
# 13          model_i3   1471
# 14          model_X3   1515
# 15  model_7er (alle)   1537
# 16          model_X6   1664
# 17          model_X1   1686
# 18          model_X4   1718
# 19          model_M4   2018
# 20          model_X5   2018
# 21          model_M3   2336
# 22  model_5er (alle)   3001
# 23  model_3er (alle)   4033
# 24  model_1er (alle)   4276
# 25  model_2er (alle)   4512
# 26  model_4er (alle)   5268

# %%
plt.figure(figsize=(12,8))
# plot barh chart with index as x values
ax = sns.barplot(y=pd_df.Model, x=pd_df.Count,palette="Blues_d")

ax.set(ylabel="Model", xlabel='Count',)
# # add proper Dim values as x labels
plt.title("Classwise Car Model Distrubution")
ax.set_yticklabels(pd_df.Model)
# for i, v in enumerate(pd_df["Count"].iteritems()):
#     #print(v)
#     ax.text(i ,v[1],"{:,}".format(v[1]), ha ='left', rotation=75)
plt.tight_layout()
plt.show()

# %%
#only "explode" the 2nd slice (i.e. 'Hogs')
#explode = (0, 0.1, 0, 0)  
fig1, ax1 = plt.subplots()
ax1.pie(np.array(list(carbodydict.values())), explode=explode, labels=np.array(list(carbodydict.keys())), autopct='%1.1f%%',
        shadow=True, startangle=90)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
X=np.array([  2268, 4347,  7026,  8661,10776,  12946])
Y=np.array([ 'Kleinwagen','Kombi', 'Cabrio',  'SUV','Coupe',
       'Limousine'], dtype='<U8')
X
# Out:
# array([ 2268,  4347,  7026,  8661, 10776, 12946])

# %%
#actual bodies
figure = plt.figure()
plt.title("Car Class Distrubution")
sns.barplot(x=X,y=Y,palette="Blues_d")
plt.xticks(rotation=45)
plt.ylabel("Car Class")
plt.xlabel("Count")
figure.set_size_inches(6,3)
plt.show()

# %%
trash= glob.glob('./../../cleaned_data/trash/**/*.jpg', recursive=True)
cars= glob.glob('./../../cleaned_data/car/**/*.jpg', recursive=True)
audi= glob.glob('./../../cleaned_data/audi/**/*.jpg', recursive=True)

# %%
len(audi)
# Out:
# 1051

# %%
len(trash)
# Out:
# 10774

# %%
#trash[0:16]

# %%
len(cars)
# Out:
# 34097

# %%
import random

# %%
image=[]

for i in range(0,16):
    x=random.randint(0, len(trash)-1)
    image.append(plt.imread(trash[i]))

# %%
plt.figure(figsize=(10, 10))

for category_num in range(1,17):
    plt.subplot(4, 4, category_num)
    plt.imshow(image[category_num-1]).axes.get_yaxis().set_visible(False)#)
    plt.xticks([])
    
plt.subplots_adjust(wspace=0.0, hspace=0.0)
plt.show()

# %%
image=[]
for i in range(16):
    x=random.randint(0, len(cars)-1)
    image.append(plt.imread(cars[x]))

# %%
plt.figure(figsize=(10, 10))

for category_num in range(1,17):
    plt.subplot(4, 4, category_num)
    plt.imshow(image[category_num-1]).axes.get_yaxis().set_visible(False)#)
    plt.xticks([])
    
plt.subplots_adjust(wspace=0.0, hspace=0.0)
plt.show()

# %%
plt.imread(cars[0]).shape[0:2]
# Out:
# (480, 640)

# %%
dim=[]
for car in cars:
    dim.append(plt.imread(car).shape[0:2])

# %%
len(dim)
# Out:
# 34097

# %%
plt.scatter(dimX,dimY)

# %%
len(dim)
# Out:
# 34097

# %%
dim[:][1]
# Out:
# (480, 640)

# %%
dimX=[]
dimY=[]

for i in range(len(dim)):
    dimX.append(dim[i][0])
    dimY.append(dim[i][1])

# %%
dimX
# Out:
# [480,
#  480,
#  480,
#  480,
#  360,
#  360,
#  360,
#  360,
#  426,
#  426,
#  426,
#  426,
#  480,
#  480,
#  425,
#  425,
#  425,
#  425,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  426,
#  426,
#  426,
#  426,
#  480,
#  427,
#  480,
#  427,
#  427,
#  427,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  427,
#  427,
#  427,
#  427,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  427,
#  427,
#  427,
#  427,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  426,
#  480,
#  480,
#  480,
#  480,
#  480,
#  360,
#  480,
#  360,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  425,
#  425,
#  425,
#  425,
#  480,
#  480,
#  480,
#  480,
#  427,
#  427,
#  427,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
#  480,
# ...
